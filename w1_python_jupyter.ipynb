# %% [markdown]
# # 01. Python, pandas, matplotlib 첫 실습
#
# 목표는 완벽한 문법 암기가 아니라, CSV 파일을 열고, 데이터를 요약하고, 그림으로 확인하는 전체 흐름을 한 번 끝까지 실행하는 것입니다.

# %% [markdown]
# ## 데이터 출처와 공식 문서
#
# - 데이터 출처: NTP/NICEATM Integrated Chemical Environment (ICE) Dataset Description
#   https://ice.ntp.niehs.nih.gov/DATASETDESCRIPTION
# - pandas documentation: https://pandas.pydata.org/docs/
# - matplotlib documentation: https://matplotlib.org/stable/users/index
# - scikit-learn documentation: https://scikit-learn.org/stable/
# - Optuna documentation: https://optuna.readthedocs.io/en/stable/

# %% [markdown]
# ## 1. Python 기본 감각
#
# - 변수: 값을 담는 이름
# - 문자열: 따옴표 안에 있는 글자
# - 리스트: 여러 값을 순서대로 담는 상자
# - 함수: 입력을 받아 정해진 작업을 수행하는 도구

# %%
course_name = "AI 첨단바이오 신약개발"
day = 1
keywords = ["python", "pandas", "matplotlib", "machine learning"]

print(course_name)
print("교육 일차:", day)
print("오늘의 키워드:", keywords)
print("첫 번째 키워드:", keywords[0])

# %%
def say_hello(name):
    message = f"{name}님, Python 실습을 시작합니다."
    return message

say_hello("수강생")
